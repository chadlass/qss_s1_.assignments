# %%
import pandas as pd
import numpy as np
from plotnine import *
from plotnine.data import *

# %%
dol = pd.read_csv("dol_dataset.csv")
dol.head()
dol.columns
# Out:
# Index(['Unnamed: 0', 'case_id', 'st_cd', 'naics_code_description',
#        'case_violtn_cnt', 'findings_start_date', 'findings_end_date',
#        'h2a_violtn_cnt', 'h2a_bw_atp_amt', 'h2a_ee_atp_cnt',
#        'h2a_cmp_assd_amt', 'ld_dt', 'start_year', 'end_year',
#        'start_month_int', 'end_month_int', 'start_quarter', 'end_quarter',
#        'ld_dt_object', 'ld_dt_year', 'ld_dt_month', 'ld_dt_quarter',
#        'total_employment'],
#       dtype='object')

# %%
## add ratio columns for backwages and CMPS
cmp_df = dol.groupby(['st_cd', 'end_year', 'total_employment']).agg({'h2a_cmp_assd_amt': ['mean', 'sum', 'count'],
                                                           'h2a_violtn_cnt' : 'sum'})

cmp_df.columns = cmp_df.columns.droplevel(0)
cmp_df.columns = ['h2a_cmp_amt_mean', 'h2a_cmp_amt_sum', 'cmp_cases',
                  'h2a_violtn_cnt_sum']

cmp_df.reset_index()

##ratio of cases actually resulting in civil monetary penalities
cmp_df['amt_pv'] = cmp_df['h2a_cmp_amt_sum'] / cmp_df['h2a_violtn_cnt_sum']
cmp_df.reset_index()
# Out:
#     st_cd  end_year  total_employment  h2a_cmp_amt_mean  h2a_cmp_amt_sum  \
# 0      AL      2004                22            6250.0          12500.0
# 1      AL      2009                22             850.0           1700.0
# 2      AL      2010                22               0.0              0.0
# 3      AL      2011                22            8435.0          16870.0
# 4      AL      2013                22            8650.0          25950.0
# ..    ...       ...               ...               ...              ...
# 913    WY      2012                 1               0.0              0.0
# 914    WY      2013                 1            2475.0           9900.0
# 915    WY      2015                 0               0.0              0.0
# 916    WY      2017                 1             900.0            900.0
# 917    WY      2018                 1               0.0              0.0
#
#      cmp_cases  h2a_violtn_cnt_sum      amt_pv
# ...

# %%
p = (ggplot(aes(x='total_employment', y='amt_pv'), cmp_df))
p + geom_point()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /opt/conda/lib/python3.8/site-packages/plotnine/mapping/evaluation.py in evaluate(aesthetics, data, env)
#     216                 try:
# --> 217                     new_val = env.eval(col, inner_namespace=data)
#     218                 except Exception as e:
#
# /opt/conda/lib/python3.8/site-packages/patsy/eval.py in eval(self, expr, source_name, inner_namespace)
#     164         code = compile(expr, source_name, "eval", self.flags, False)
# --> 165         return eval(code, {}, VarLookupDict([inner_namespace]
#     166                                             + self._namespaces))
#
# <string> in <module>
#
# NameError: name 'total_employment' is not defined
#
# During handling of the above exception, another exception occurred:
#
# PlotnineError                             Traceback (most recent call last)
# ...

# %%
One_plot = (ggplot(cmp_df, aes(etc)) + geom_point())
